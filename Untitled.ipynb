# %%
import pandas as pd

# %%
## total housing units 1990, 2000, 2010, 2020
df = pd.read_csv('./nhgis0001_ts_geog2010_blck_grp.csv', low_memory=False)

# %%
df
# Out:
#                 GISJOIN  GEOGYEAR    STATE  STATEA          COUNTY  COUNTYA  \
# 0       G01000100201001      2010  Alabama       1  Autauga County        1
# 1       G01000100201002      2010  Alabama       1  Autauga County        1
# 2       G01000100202001      2010  Alabama       1  Autauga County        1
# 3       G01000100202002      2010  Alabama       1  Autauga County        1
# 4       G01000100203001      2010  Alabama       1  Autauga County        1
# ...                 ...       ...      ...     ...             ...      ...
# 217735  G56004509511001      2010  Wyoming      56   Weston County       45
# 217736  G56004509511002      2010  Wyoming      56   Weston County       45
# 217737  G56004509513001      2010  Wyoming      56   Weston County       45
# 217738  G56004509513002      2010  Wyoming      56   Weston County       45
# 217739  G56004509513003      2010  Wyoming      56   Weston County       45
#
# ...

# %%
LA = df[df['COUNTY']=='Los Angeles County']

# %%
LA
# Out:
#                GISJOIN  GEOGYEAR       STATE  STATEA              COUNTY  \
# 13843  G06003701011101      2010  California       6  Los Angeles County
# 13844  G06003701011102      2010  California       6  Los Angeles County
# 13845  G06003701011103      2010  California       6  Los Angeles County
# 13846  G06003701011221      2010  California       6  Los Angeles County
# 13847  G06003701011222      2010  California       6  Los Angeles County
# ...                ...       ...         ...     ...                 ...
# 20263  G06003709800311      2010  California       6  Los Angeles County
# 20264  G06003709800331      2010  California       6  Los Angeles County
# 20265  G06003709901000      2010  California       6  Los Angeles County
# 20266  G06003709902000      2010  California       6  Los Angeles County
# 20267  G06003709903000      2010  California       6  Los Angeles County
#
#        COUNTYA  TRACTA  BLCK_GRPA  CM7AA1990  CM7AA1990L  CM7AA1990U  \
# ...

# %%
LA_housing_1990 = LA['CM7AA1990']

# %%
LA_housing_1990.plot()
LA_housing_1990.mean()
# Out:
# 492.3396918287938

# %%
LA_housing_1990.plot(kind="hist", bins=30, edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
LA_housing_2000 = LA['CM7AA2000']
LA_housing_2000.plot()
LA_housing_2000.mean()
# Out:
# 509.0774178988327

# %%
LA_housing_2000.plot(kind="hist", bins=30, edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
LA_housing_2010 = LA['CM7AA2010']
LA_housing_2010.plot()
LA_housing_2010.mean()
# Out:
# 536.1985992217899

# %%
LA_housing_2010.plot(kind="hist", bins=30, edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
LA_housing_2020 = LA['CM7AA2020']
LA_housing_2020.plot()
LA_housing_2020.mean()
# Out:
# 559.0620342412452

# %%
LA_housing_2020.plot(kind="hist", bins=30, edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>
